# %% [markdown]
# <a href="https://colab.research.google.com/github/noturnon2/myshare/blob/master/Analise%20de%20Partidas%20de%20Futebol%20usando%20Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pip install pandas

# %%
import pandas as pd

# %% [markdown]
# Realizando a leitura dos dados
#
# Podemos abrir diversos tipos de arquivos com a biblioteca pandas:
#
# pd.read_csv()
# pd.read_excel()
# pd.read_json()
# pd.read_html()

# %%
dados = pd.read_csv('/content/sample_data/campeonato-brasileiro-full.csv', sep =  ",")

# %%
dados.head(10)
# Out:
#    ID  rodata        data   hora       mandante    visitante  \
# 0   1       1  29/03/2003  16:00        Guarani        Vasco
# 1   2       1  29/03/2003  16:00   Athletico-PR       Gremio
# 2   3       1  30/03/2003  16:00       Flamengo     Coritiba
# 3   4       1  30/03/2003  16:00          Goias     Paysandu
# 4   5       1  30/03/2003  16:00  Internacional  Ponte Preta
# 5   6       1  30/03/2003  16:00       Criciuma   Fluminense
# 6   7       1  30/03/2003  16:00      Juventude    Sao Paulo
# 7   8       1  30/03/2003  16:00      Fortaleza        Bahia
# 8   9       1  30/03/2003  16:00       Cruzeiro  Sao Caetano
# 9  10       1  30/03/2003  16:00        Vitoria  Figueirense
#
#   formacao_mandante formacao_visitante tecnico_mandante tecnico_visitante  \
# 0               NaN                NaN              NaN               NaN
# 1               NaN                NaN              NaN               NaN
# ...

# %%
dados.shape
# Out:
# (8405, 16)

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8405 entries, 0 to 8404
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  8405 non-null   int64
#  1   rodata              8405 non-null   int64
#  2   data                8405 non-null   object
#  3   hora                8405 non-null   object
#  4   mandante            8405 non-null   object
#  5   visitante           8405 non-null   object
#  6   formacao_mandante   3431 non-null   object
#  7   formacao_visitante  3431 non-null   object
#  8   tecnico_mandante    3795 non-null   object
#  9   tecnico_visitante   3795 non-null   object
#  10  vencedor            8405 non-null   object
#  11  arena               8405 non-null   object
#  12  mandante_Placar     8405 non-null   int64
#  13  visitante_Placar    8405 non-null   int64
#  14  mandante_Estado     8405 non-null   object
# ...

# %%
colunas = {"", ""}
# dados = dados.drop(columns  = colunas, axis = 1)
dados.columns
# Out:
# Index(['ID', 'rodata', 'data', 'hora', 'mandante', 'visitante',
#        'formacao_mandante', 'formacao_visitante', 'tecnico_mandante',
#        'tecnico_visitante', 'vencedor', 'arena', 'mandante_Placar',
#        'visitante_Placar', 'mandante_Estado', 'visitante_Estado'],
#       dtype='object')

# %%
dados.describe(include = "all")
# Out:
#                 ID       rodata        data   hora   mandante visitante  \
# count   8405.00000  8405.000000        8405   8405       8405      8405
# unique         NaN          NaN        1943    186         45        45
# top            NaN          NaN  06/07/2008  16:00  Sao Paulo  Flamengo
# freq           NaN          NaN          15   1897        409       410
# mean    4203.00000    20.133254         NaN    NaN        NaN       NaN
# std     2426.45884    11.444643         NaN    NaN        NaN       NaN
# min        1.00000     1.000000         NaN    NaN        NaN       NaN
# 25%     2102.00000    10.000000         NaN    NaN        NaN       NaN
# 50%     4203.00000    20.000000         NaN    NaN        NaN       NaN
# 75%     6304.00000    30.000000         NaN    NaN        NaN       NaN
# max     8405.00000    46.000000         NaN    NaN        NaN       NaN
#
#        formacao_mandante formacao_visitante      tecnico_mandante  \
# ...

# %%
#dados[["partida_id", "clube", "rodata", "chutes", "chutes_no_alvo", "faltas", "posse_de_bola"]]

# %%
dados["mandante"] == "Palmeiras"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8400    False
# 8401    False
# 8402    False
# 8403    False
# 8404    False
# Name: mandante, Length: 8405, dtype: bool

# %%
dados.isna()
# Out:
#          ID  rodata   data   hora  mandante  visitante  formacao_mandante  \
# 0     False   False  False  False     False      False               True
# 1     False   False  False  False     False      False               True
# 2     False   False  False  False     False      False               True
# 3     False   False  False  False     False      False               True
# 4     False   False  False  False     False      False               True
# ...     ...     ...    ...    ...       ...        ...                ...
# 8400  False   False  False  False     False      False              False
# 8401  False   False  False  False     False      False              False
# 8402  False   False  False  False     False      False              False
# 8403  False   False  False  False     False      False              False
# 8404  False   False  False  False     False      False              False
#
#       formacao_visitante  tecnico_mandante  tecnico_visitante  vencedor  \
# ...

# %%
dados.isna().sum()
# Out:
# ID                       0
# rodata                   0
# data                     0
# hora                     0
# mandante                 0
# visitante                0
# formacao_mandante     4974
# formacao_visitante    4974
# tecnico_mandante      4610
# tecnico_visitante     4610
# vencedor                 0
# arena                    0
# mandante_Placar          0
# visitante_Placar         0
# mandante_Estado          0
# visitante_Estado         0
# dtype: int64

# %%
""" colunas = []
for coluna in dados.columns:
  if dados[coluna].isna().sum() != 0:
    colunas.append(coluna)
dados[coluna] """
# Out:
# ' colunas = []\nfor coluna in dados.columns:\n  if dados[coluna].isna().sum() != 0:\n    colunas.append(coluna)\ndados[coluna] '

# %%
dados.fillna(0, inplace = True)

# %%
 # dados.fillna.sum()

# dados['Tempo em Campo'] == 0

dados.groupby("vencedor").mean("mandante_Placar")
# Out:
#                           ID     rodata  mandante_Placar  visitante_Placar
# vencedor
# -                4279.613237  19.528591         0.971184          0.971184
# America-MG       6685.879310  21.172414         1.689655          0.862069
# America-RN       2037.250000  13.500000         1.750000          1.750000
# Athletico-PR     4309.475728  21.126214         1.812298          0.990291
# Atletico-GO      5655.194444  21.027778         1.666667          1.166667
# Atletico-MG      4740.189602  20.122324         1.831804          1.113150
# Avai             4730.212121  19.727273         1.712121          1.045455
# Bahia            5381.732283  20.322835         1.637795          0.992126
# Barueri          2884.083333  18.166667         2.666667          1.000000
# Botafogo-RJ      4385.040486  19.044534         1.700405          1.048583
# Bragantino       7677.581818  19.800000         1.690909          1.036364
# ...

# %%
dados["mandante_Estado"] == "RJ"
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 8400    False
# 8401    False
# 8402    False
# 8403    False
# 8404     True
# Name: mandante_Estado, Length: 8405, dtype: bool

# %%
dados.groupby('mandante').median('mandante_Placar')#.round(2)
# Out:
#                      ID  rodata  mandante_Placar  visitante_Placar
# mandante
# America-MG       6886.0    19.0              1.0               1.0
# America-RN       2118.0    19.0              0.0               1.0
# Athletico-PR     4508.5    20.0              1.0               1.0
# Atletico-GO      5921.0    20.0              1.0               1.0
# Atletico-MG      4510.0    20.0              2.0               1.0
# Avai             5171.0    19.0              1.0               1.0
# Bahia            5910.0    20.0              1.0               1.0
# Barueri          2900.0    20.0              2.0               1.0
# Botafogo-RJ      4154.0    20.0              1.0               1.0
# Bragantino       7652.5    19.5              1.0               1.0
# Brasiliense      1349.0    23.0              1.0               2.0
# CSA              6685.0    18.0              1.0               1.0
# Ceara            6689.0    19.0              1.0               1.0
# ...

# %%
soma_dados = dados.groupby("vencedor").max("mandante_Placar")
soma_dados.head()
# Out:
#                 ID  rodata  mandante_Placar  visitante_Placar
# vencedor
# -             8400      46                5                 5
# America-MG    8391      38                4                 4
# America-RN    2078      29                3                 3
# Athletico-PR  8395      44                7                 6
# Atletico-GO   7973      38                5                 4

# %%
#soma_dados2 = dados.count(['visitante'] and ['vencedor'] == 'Palmeiras')
#print(soma_dados2)

# %%
#dados[['mandante', 'visitante', 'mandante_Placar', 'visitante_Placar', 'vencedor']].sort_values("vencedor", ascending = False)

# %%
dados[['mandante', 'visitante', 'mandante_Placar', 'visitante_Placar', 'vencedor']].sort_values("vencedor")
# Out:
#            mandante      visitante  mandante_Placar  visitante_Placar vencedor
# 7069    Atletico-GO    Corinthians                1                 1        -
# 4206          Vasco       Flamengo                1                 1        -
# 7533  Internacional    Corinthians                2                 2        -
# 1908          Vasco      Juventude                1                 1        -
# 4204     Portuguesa         Gremio                2                 2        -
# ...             ...            ...              ...               ...      ...
# 3148        Vitoria   Athletico-PR                1                 0  Vitoria
# 5421        Vitoria  Internacional                1                 0  Vitoria
# 3123        Vitoria    Atletico-MG                4                 3  Vitoria
# 1047        Vitoria         Gremio                2                 0  Vitoria
# 3232       Cruzeiro        Vitoria                0                 1  Vitoria
#
# [8405 rows x 5 columns]

# %%
dados.to_csv("/content/sample_data/dados_campeonato.csv", index = False)
